# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('bostonhouseprice.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
# Provides some information regarding the columns in the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
# this describes the basic stat behind the dataset used 
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
Y = df.MEDV
Y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
X = df.drop(['MEDV'], axis=1)
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %% [markdown]
# # DATA SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
#dimension
X_train.shape, Y_train.shape
# Out:
# ((404, 13), (404,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((102, 13), (102,))

# %% [markdown]
# # LINEAR REGRESSION MODEL

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([34.06254055, 29.29371639, 15.64698581, 18.46682036, 35.3228949 ,
#        18.71419844, 20.18345664, 20.01261788, 10.2114329 , 23.03232996,
#        24.01080947, 22.2559431 , 13.5615076 , 14.10531349, 13.31151099,
#        33.40607236, 18.27251992, 16.92230033, 14.91154549, 20.21836487,
#        17.00356985, 19.56859717, 16.51492146, 28.49291093, 21.02811587,
#        38.2482081 , 13.84552867, 27.28343603, 12.86615822, 28.86293459,
#        16.71250617, 20.02447017, 13.50718555, 30.18983039, 29.77150475,
#        35.79376843, 12.5984626 , 17.37432955, 27.80125835,  7.42234218,
#        16.34238629,  8.87592145, 32.93881703, 23.46942363, 29.40493341,
#        34.50507379, 17.96609711, 16.68774712, 36.56362631, 21.99768924,
#        20.91694302, 20.01395711, 17.77965863, 20.26145505, 20.31412751,
#        33.38498493, 35.14441508, 15.20250753, 20.02420901,  3.60222935,
#        15.12226768, 11.85228893, 13.52054912, 19.89811847, 18.70445198,
#         7.93643973, 20.21422186, 24.04359107, 30.44862133, 13.59424465,
#        22.95250293, 13.6399799 , 18.25770179, 24.40482255, 22.39096059,
#        10.23816544, 40.67766658,  7.67889155, 22.23138665, 28.25896913,
#        20.87644652, 27.39745169, 19.46693541, 26.31185661, 20.25871508,
#         6.40788803, 20.20342262, 21.22748178, 14.86178451, 25.37797487,
#        18.76526852, 17.91416134, 23.50528761, 37.49136856, 20.4901811 ,
#        33.55318809, 30.89759496, 26.59312125, 20.37689843, 17.03154917,
#        26.8892525 , 25.46537561])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,Y_train)
y_pred = lr.predict(X_test)

# %%
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y_test, Y_pred))
# Out:
# Coefficients: [-1.07841908e-01  5.33348632e-02  4.34998390e-02  3.05538824e+00
#  -1.85932011e+01  3.41330545e+00  5.93635207e-05 -1.51153416e+00
#   3.28867952e-01 -1.13058440e-02 -9.30822256e-01  8.64998271e-03
#  -5.86732340e-01]
# Intercept: 39.19862854597204
# Mean squared error (MSE): 18.11

# %%
from sklearn.metrics import r2_score,mean_squared_error
rsq = r2_score(Y_test,Y_pred)
print('r square :',rsq)
# Out:
# r square : 0.776460695145958

# %%
import numpy as np
import seaborn as sns
np.array(Y_test)
# Out:
# array([35.4, 25. , 15.6, 12.7, 33.1, 14.5, 20.4, 20. ,  8.3, 20.2, 23.1,
#        26.4, 13.5, 13.4, 15.6, 31.6, 18.9, 10.2,  9.6, 18.3, 17.8, 14.6,
#        17.5, 23.7, 19. , 45.4, 15.7, 23.2, 10.5, 22. , 19.3, 19.2, 13.4,
#        34.7, 24. , 33.2, 16.3, 17.1, 26.6,  8.5, 17.6, 17.8, 31.7, 24.4,
#        24.3, 34.9, 19.8, 19.4, 48.3, 20.6, 21.4, 27.5, 18.7, 18.8, 18.7,
#        37.9, 50. , 16.2, 16.7,  8.1, 15.2, 12. , 13.3, 17.1, 27.1,  7.2,
#        19.1, 26.2, 34.9, 19.7, 23.2, 11.3, 16. , 25. , 16.1, 16.5, 50. ,
#        14.6, 21.7, 33.4, 20.9, 36.2, 19.6, 22.8, 17.8, 10.5, 20.5, 16.8,
#        10.9, 23.2, 16.1,  7.2, 20.3, 41.7, 21.5, 31. , 23.5, 22.3, 21. ,
#        18.1, 24.8, 21.6])

# %%
Y_test
# Out:
# 281    35.4
# 482    25.0
# 146    15.6
# 394    12.7
# 277    33.1
#        ...
# 169    22.3
# 29     21.0
# 135    18.1
# 289    24.8
# 313    21.6
# Name: MEDV, Length: 102, dtype: float64

# %%
Y_pred
# Out:
# array([34.06254055, 29.29371639, 15.64698581, 18.46682036, 35.3228949 ,
#        18.71419844, 20.18345664, 20.01261788, 10.2114329 , 23.03232996,
#        24.01080947, 22.2559431 , 13.5615076 , 14.10531349, 13.31151099,
#        33.40607236, 18.27251992, 16.92230033, 14.91154549, 20.21836487,
#        17.00356985, 19.56859717, 16.51492146, 28.49291093, 21.02811587,
#        38.2482081 , 13.84552867, 27.28343603, 12.86615822, 28.86293459,
#        16.71250617, 20.02447017, 13.50718555, 30.18983039, 29.77150475,
#        35.79376843, 12.5984626 , 17.37432955, 27.80125835,  7.42234218,
#        16.34238629,  8.87592145, 32.93881703, 23.46942363, 29.40493341,
#        34.50507379, 17.96609711, 16.68774712, 36.56362631, 21.99768924,
#        20.91694302, 20.01395711, 17.77965863, 20.26145505, 20.31412751,
#        33.38498493, 35.14441508, 15.20250753, 20.02420901,  3.60222935,
#        15.12226768, 11.85228893, 13.52054912, 19.89811847, 18.70445198,
#         7.93643973, 20.21422186, 24.04359107, 30.44862133, 13.59424465,
#        22.95250293, 13.6399799 , 18.25770179, 24.40482255, 22.39096059,
#        10.23816544, 40.67766658,  7.67889155, 22.23138665, 28.25896913,
#        20.87644652, 27.39745169, 19.46693541, 26.31185661, 20.25871508,
#         6.40788803, 20.20342262, 21.22748178, 14.86178451, 25.37797487,
#        18.76526852, 17.91416134, 23.50528761, 37.49136856, 20.4901811 ,
#        33.55318809, 30.89759496, 26.59312125, 20.37689843, 17.03154917,
#        26.8892525 , 25.46537561])

# %%
sns.scatterplot(Y_test, Y_pred)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MEDV'>

# %%
sns.scatterplot(Y_test, Y_pred, alpha=0.5)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MEDV'>
